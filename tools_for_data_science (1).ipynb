# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ### My name is md saif haider and I am an aspiring Data Scientist

# %% [markdown]
# *I am interested in data science becasue I love to gain insights from data*

# %% [markdown]
# #### Itz adding two Number and comparing their sum to the sum of all values that can be produced within the range 3

# %%
def add(x,y):
    return x+y
add(2,1)==sum(range(3))
# Out:
# True

# %% [markdown]
# <ol>
#   <p>This is some info.</p>
#   <li>This is question one.</li>
#   <p>This is more info.</p>
#   <li>This is question two.</li>
#     <a>www.ibm.com</a>
# </ol>
